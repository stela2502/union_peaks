# %%
from __future__ import with_statement # for 2.5, does nothing in 2.6
from gzip import open as gzopen

with gzopen('A.tsv.gz') as gzfile:
    for line in gzfile:
      print(line.decode('utf-8'))
# Out:
# ENSG00000157933	SKI	Gene Expression	chr1	2228318	2228319
#
# ENSG00000054523	KIF1B	Gene Expression	chr1	10210804	10232329
#
# ENSG00000116685	KIAA2013	Gene Expression	chr1	11926402	11926428
#
# ENSG00000117245	KIF17	Gene Expression	chr1	20717490	20718017
#
# ENSG00000162522	KIAA1522	Gene Expression	chr1	32741829	32765667
#
# ENSG00000142687	KIAA0319L	Gene Expression	chr1	35454706	35557403
#
# ENSG00000174574	AKIRIN1	Gene Expression	chr1	38991275	38991288
#
# ENSG00000142945	KIF2C	Gene Expression	chr1	44739836	44746406
#
# ENSG00000116299	KIAA1324	Gene Expression	chr1	109114114	109114155
#
# ENSG00000183853	KIRREL1	Gene Expression	chr1	157993272	158086680
#
# ENSG00000226520	KIRREL1-IT1	Gene Expression	chr1	158025549	158025550
#
# ENSG00000075945	KIFAP3	Gene Expression	chr1	170068916	170074738
#
# ENSG00000235750	KIAA0040	Gene Expression	chr1	175166740	175192943
#
# ENSG00000135835	KIAA1614	Gene Expression	chr1	180912896	180928147
#
# ...
